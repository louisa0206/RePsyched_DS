# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\annav\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\annav\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\annav\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\annav\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\annav\anaconda3\lib\site-packages (from pandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\annav\anaconda3\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\users\annav\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)

# %%
import requests

# %%
import bs4
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.berlin.de/special/immobilien-und-wohnen/adressen/recyclinghof/'

# %%
headers = {
"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"
}

# %%
r = requests.get(url, {'headers': headers})

# %%
soup = bs4.BeautifulSoup(r.text,'html.parser')

# %%
recyclinghoefe_adressen = {}
adresse_no = 0

items = soup.find_all('span',{'class':'address'})
    
for item in items:
        
        adressen = item.get_text()
        adressen1 = adressen.replace('\n', '').replace('\r', '')
        adressen2 = adressen1.replace('           ', '')
        adressen3 = adressen2.replace('     ', '')
        
    
        
        print(adressen3)
    
        adresse_no +=1
        
        recyclinghoefe_adressen[adresse_no] = [adressen3]
# Out:
# Miraustr. 35, 13509 Berlin–Reinickendorf
# Asgardstraße 3, 13089 Berlin–Weißensee
# Behmstraße 74, 10439 Berlin–Prenzlauer Berg
# Berliner Straße 110, 10713 Berlin–Wilmersdorf
# Brunsbütteler Damm 47, 13581 Berlin–Spandau
# Fischerstraße 16, 10317 Berlin–Lichtenberg
# Gradestraße 77, 12347 Berlin–Neukölln
# Hegauer Weg 17, 14163 Berlin–Zehlendorf
# Ilsenburger Straße 18-20, 10589 Berlin–Charlottenburg
# Lengeder Straße 6-18, 13407 Berlin–Reinickendorf
# Naumannstraße 88-92, 10829 Berlin–Schöneberg

# %%
print (recyclinghoefe_adressen)
# Out:
# {1: ['Miraustr. 35, 13509 Berlin–Reinickendorf'], 2: ['Asgardstraße 3, 13089 Berlin–Weißensee'], 3: ['Behmstraße 74, 10439 Berlin–Prenzlauer Berg'], 4: ['Berliner Straße 110, 10713 Berlin–Wilmersdorf'], 5: ['Brunsbütteler Damm 47, 13581 Berlin–Spandau'], 6: ['Fischerstraße 16, 10317 Berlin–Lichtenberg'], 7: ['Gradestraße 77, 12347 Berlin–Neukölln'], 8: ['Hegauer Weg 17, 14163 Berlin–Zehlendorf'], 9: ['Ilsenburger Straße 18-20, 10589 Berlin–Charlottenburg'], 10: ['Lengeder Straße 6-18, 13407 Berlin–Reinickendorf'], 11: ['Naumannstraße 88-92, 10829 Berlin–Schöneberg']}

# %%
recyclinghoefe_adressen_df = pd.DataFrame.from_dict(recyclinghoefe_adressen, orient = 'index', columns = ['Adresse'])


recyclinghoefe_adressen_df.to_csv('recyclinghoefe_adressen.csv')

# %%
recyclinghoefe_adressen_df.to_csv('recyclinghoefe_locations1.csv')
